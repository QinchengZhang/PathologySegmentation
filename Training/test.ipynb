# %%
from models import *
import torch

# %%
x = torch.ones(4, 3, 128, 128)
x = x.to('cuda')
hsunet = HSU_Net(3, 1, 5).to('cuda')
y = hsunet(x)
y.shape
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-8054a056b399> in <module>
#       2 x = x.to('cuda')
#       3 hsunet = HSU_Net(3, 1, 5).to('cuda')
# ----> 4 y = hsunet(x)
#       5 y.shape
#
# D:\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# g:\TJUZQC\code\python\PathologySegmentation\Training\models\hsunet.py in forward(self, x)
#      53     def forward(self,x):
#      54         # encoding path
# ---> 55         x1 = self.Conv1(x)
#      56
#      57         x2 = self.Maxpool(x1)
#
# ...
